# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import torch
# import torch.nn as nn
# import torch.optim as optim

# %%
dataset_gw = pd.read_csv('gw.csv')
dataset_gw.set_index('yyyymm', inplace=True, format='%Y%m')
dataset_gw.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 dataset_gw = pd.read_csv('gw.csv')
# ----> 2 dataset_gw.set_index('yyyymm', inplace=True, format='%Y%m')
#       3 dataset_gw.head()
#
# TypeError: DataFrame.set_index() got an unexpected keyword argument 'format'
